# %% [markdown]
# # Modelling in Pycomo initial 10 species with Normal people

# %%
from pathlib import Path
import sys
import cobra
import os

# %% [markdown]
# ### Importing PyCoMo

# %%
path_root = Path("C:/Users/tobyl/OneDrive - The University of Manchester/Bioinformatics Masters/Research Project 2/Pycomo/PyCoMo/src")
sys.path.append(str(path_root))
import pycomo

# %% [markdown]
# ### Creating community model
# 1. Load the member models

# %%
# loading member models
model_member_dir = Path("models_members/Control")
named_models = pycomo.load_named_models_from_dir(model_member_dir)

# %%
# checking modesl that have been loaded
print(named_models)
# Out:
# {'Alistipes_putredinis_DSM_17216': <Model Alistipes_putredinis_DSM_17216 at 0x200e1e426f0>, 'Bacteroides_uniformis_ATCC_8492': <Model Bacteroides_uniformis_ATCC_8492 at 0x200e379c3b0>, 'Bacteroides_vulgatus_ATCC_8482': <Model Bacteroides_vulgatus_ATCC_8482 at 0x200e373cbf0>, 'Bifidobacterium_adolescentis_ATCC_15703': <Model Bifidobacterium_adolescentis_ATCC_15703 at 0x200f2440380>, 'Bifidobacterium_longum_E18': <Model Bifidobacterium_longum_E18 at 0x200f2266510>, 'Escherichia_coli_UTI89_UPEC': <Model Escherichia_coli_UTI89_UPEC at 0x200f3948080>, 'Eubacterium_rectale_ATCC_33656': <Model Eubacterium_rectale_ATCC_33656 at 0x200f47cc0e0>, 'Faecalibacterium_prausnitzii_M21_2': <Model Faecalibacterium_prausnitzii_M21_2 at 0x200f48f40b0>, 'Prevotella_copri_CB7_DSM_18205': <Model Prevotella_copri_CB7_DSM_18205 at 0x200f4ac3ce0>, 'Ruminococcus_bromii_L2_63': <Model Ruminococcus_bromii_L2_63 at 0x200f6d203b0>}

# %% [markdown]
# 2. checking the objective function of the loaded models

# %%
# if all have a biomass objective function then it is working
for model in named_models.values():
    print(model.objective)
# Out:
# Maximize
# 1.0*biomass374 - 1.0*biomass374_reverse_59177
# Maximize
# 1.0*biomass536 - 1.0*biomass536_reverse_50d4e
# Maximize
# 1.0*biomass345 - 1.0*biomass345_reverse_e128f
# Maximize
# 1.0*biomass345 - 1.0*biomass345_reverse_e128f
# Maximize
# 1.0*biomass345 - 1.0*biomass345_reverse_e128f
# Maximize
# 1.0*biomass525 - 1.0*biomass525_reverse_5c178
# Maximize
# 1.0*biomass205 - 1.0*biomass205_reverse_3c9be
# Maximize
# 1.0*biomass224 - 1.0*biomass224_reverse_c48a3
# Maximize
# 1.0*biomass525 - 1.0*biomass525_reverse_5c178
# Maximize
# 1.0*biomass525 - 1.0*biomass525_reverse_5c178

# %%
# creating the single organism models in PyCoMo format
single_org_models = []
for name, model in named_models.items():
    print(name)
    single_org_model = pycomo.SingleOrganismModel(model, name)
    single_org_models.append(single_org_model)
# Out:
# Alistipes_putredinis_DSM_17216
# Bacteroides_uniformis_ATCC_8492
# Bacteroides_vulgatus_ATCC_8482
# Bifidobacterium_adolescentis_ATCC_15703
# Bifidobacterium_longum_E18
# Escherichia_coli_UTI89_UPEC
# Eubacterium_rectale_ATCC_33656
# Faecalibacterium_prausnitzii_M21_2
# Prevotella_copri_CB7_DSM_18205
# Ruminococcus_bromii_L2_63

# %% [markdown]
# 3. Creating the community model

# %%
community_name = "ten_gutControl_model"
com_model_obj = pycomo.CommunityModel(single_org_models, community_name)

# %%
# calling the community model to make it
com_model_obj.model
# Out:
# No community model generated yet. Generating now:
# Note: no products in the objective function, adding biomass to it.
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Note: no products in the objective function, adding biomass to it.
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# WARNING: no annotation overlap found for matching metabolite hg2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite cobalt2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite mg2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite zn2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite pb. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite _26dap_M. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite isocapr. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite mn2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite cro4. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite cd2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite indole. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite cu2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# Ignoring reaction 'EX__26dap_M_medium' since it already exists.
# Ignoring reaction 'EX_C02528_medium' since it already exists.
# Ignoring reaction 'EX_ac_medium' since it already exists.
# Ignoring reaction 'EX_adn_medium' since it already exists.
# Ignoring reaction 'EX_ala_L_medium' since it already exists.
# Ignoring reaction 'EX_arg_L_medium' since it already exists.
# Ignoring reaction 'EX_asn_L_medium' since it already exists.
# Ignoring reaction 'EX_ca2_medium' since it already exists.
# Ignoring reaction 'EX_cd2_medium' since it already exists.
# Ignoring reaction 'EX_cholate_medium' since it already exists.
# Ignoring reaction 'EX_cit_medium' since it already exists.
# Ignoring reaction 'EX_cl_medium' since it already exists.
# Ignoring reaction 'EX_co2_medium' since it already exists.
# Ignoring reaction 'EX_cobalt2_medium' since it already exists.
# Ignoring reaction 'EX_cro4_medium' since it already exists.
# Ignoring reaction 'EX_cu2_medium' since it already exists.
# Ignoring reaction 'EX_cys_L_medium' since it already exists.
# Ignoring reaction 'EX_cytd_medium' since it already exists.
# Ignoring reaction 'EX_dad_2_medium' since it already exists.
# Ignoring reaction 'EX_dcyt_medium' since it already exists.
# Ignoring reaction 'EX_dgchol_medium' since it already exists.
# Ignoring reaction 'EX_dgsn_medium' since it already exists.
# Ignoring reaction 'EX_din_medium' since it already exists.
# Ignoring reaction 'EX_duri_medium' since it already exists.
# Ignoring reaction 'EX_fe2_medium' since it already exists.
# Ignoring reaction 'EX_fe3_medium' since it already exists.
# Ignoring reaction 'EX_gchola_medium' since it already exists.
# Ignoring reaction 'EX_gly_medium' since it already exists.
# Ignoring reaction 'EX_gsn_medium' since it already exists.
# Ignoring reaction 'EX_h2_medium' since it already exists.
# Ignoring reaction 'EX_h2o_medium' since it already exists.
# Ignoring reaction 'EX_h_medium' since it already exists.
# Ignoring reaction 'EX_hdca_medium' since it already exists.
# Ignoring reaction 'EX_hg2_medium' since it already exists.
# Ignoring reaction 'EX_indole_medium' since it already exists.
# Ignoring reaction 'EX_ins_medium' since it already exists.
# Ignoring reaction 'EX_isobut_medium' since it already exists.
# Ignoring reaction 'EX_isocapr_medium' since it already exists.
# Ignoring reaction 'EX_isoval_medium' since it already exists.
# Ignoring reaction 'EX_k_medium' since it already exists.
# Ignoring reaction 'EX_lac_D_medium' since it already exists.
# Ignoring reaction 'EX_leu_L_medium' since it already exists.
# Ignoring reaction 'EX_lys_L_medium' since it already exists.
# Ignoring reaction 'EX_met_L_medium' since it already exists.
# Ignoring reaction 'EX_mg2_medium' since it already exists.
# Ignoring reaction 'EX_mn2_medium' since it already exists.
# Ignoring reaction 'EX_na1_medium' since it already exists.
# Ignoring reaction 'EX_nac_medium' since it already exists.
# Ignoring reaction 'EX_nh4_medium' since it already exists.
# Ignoring reaction 'EX_o2_medium' since it already exists.
# Ignoring reaction 'EX_ocdca_medium' since it already exists.
# Ignoring reaction 'EX_pb_medium' since it already exists.
# Ignoring reaction 'EX_phe_L_medium' since it already exists.
# Ignoring reaction 'EX_pheme_medium' since it already exists.
# Ignoring reaction 'EX_pi_medium' since it already exists.
# Ignoring reaction 'EX_ppa_medium' since it already exists.
# Ignoring reaction 'EX_ppi_medium' since it already exists.
# Ignoring reaction 'EX_ser_L_medium' since it already exists.
# Ignoring reaction 'EX_so4_medium' since it already exists.
# Ignoring reaction 'EX_spmd_medium' since it already exists.
# Ignoring reaction 'EX_succ_medium' since it already exists.
# Ignoring reaction 'EX_taur_medium' since it already exists.
# Ignoring reaction 'EX_tchola_medium' since it already exists.
# Ignoring reaction 'EX_tdchola_medium' since it already exists.
# Ignoring reaction 'EX_thr_L_medium' since it already exists.
# Ignoring reaction 'EX_thymd_medium' since it already exists.
# Ignoring reaction 'EX_trp_L_medium' since it already exists.
# Ignoring reaction 'EX_ttdca_medium' since it already exists.
# Ignoring reaction 'EX_urea_medium' since it already exists.
# Ignoring reaction 'EX_uri_medium' since it already exists.
# Ignoring reaction 'EX_val_L_medium' since it already exists.
# Ignoring reaction 'EX_zn2_medium' since it already exists.
# Note: no products in the objective function, adding biomass to it.
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# WARNING: no annotation overlap found for matching metabolite core6. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite core4_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn118_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn114_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn190. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn8. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn126_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn79. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn152. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn164. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn30_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn95_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn14_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn172_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn107_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn112_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn176. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite mantr. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn63. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn115_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn31. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn149. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite _26dap_M. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn188_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn87. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn68_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite cro4. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn163. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn161_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn29. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn22. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn90. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn57_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn145. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite rmn. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn86_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite agam1b3agal. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn154_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn103_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn25. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn62_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite kesto. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn58. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn31_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite cobalt2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn48_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn116. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn117_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn66_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn121. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn19_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn24_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn187_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn72_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn42_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn62. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn165_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn141. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn156. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite glygn5. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn92. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn148. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn116_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn182_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn118. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn90_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite core3. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn128. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn10_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite Tyr_ggn. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn36. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn41_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn69_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn64. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn123_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn147_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn191. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn195. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn129. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn80_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn132_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn89. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn106. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn126. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn170_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn167_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn18. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn99. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite dsT_antigen. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn35_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn2_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn58_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn65. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn24. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn189. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn142. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn81_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite gal1a3acgal. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn82_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn141_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn173_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn173. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn34_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn41. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn73. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn68. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn108_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn135_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn88_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn18_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn180_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn42. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn120_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn136. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn59. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn179. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn127_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn105. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn97. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite acnam2a6agal. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn143_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn120. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn76_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite core2_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn123. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn147. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn122_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn110_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn113_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn4_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn7. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn196. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn121_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn38_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn85_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn32_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn55_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn111. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn135. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn81. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn169_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite cd2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn160. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn10. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn40. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn177_rl. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING: no annotation overlap found for matching metabolite MGlcn35. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# ...
# Ignoring reaction 'EX_fe2_medium' since it already exists.
# Ignoring reaction 'EX_fe3_medium' since it already exists.
# Ignoring reaction 'EX_for_medium' since it already exists.
# Ignoring reaction 'EX_fru_medium' since it already exists.
# Ignoring reaction 'EX_gal1b3acgal_medium' since it already exists.
# Ignoring reaction 'EX_gal_medium' since it already exists.
# Ignoring reaction 'EX_gchola_medium' since it already exists.
# Ignoring reaction 'EX_glc_D_medium' since it already exists.
# Ignoring reaction 'EX_glu_L_medium' since it already exists.
# Ignoring reaction 'EX_gly_medium' since it already exists.
# Ignoring reaction 'EX_glyasp_medium' since it already exists.
# Ignoring reaction 'EX_gncore1_medium' since it already exists.
# Ignoring reaction 'EX_gncore1_rl_medium' since it already exists.
# Ignoring reaction 'EX_gncore2_medium' since it already exists.
# Ignoring reaction 'EX_gncore2_rl_medium' since it already exists.
# Ignoring reaction 'EX_gthox_medium' since it already exists.
# Ignoring reaction 'EX_gthrd_medium' since it already exists.
# Ignoring reaction 'EX_h2o_medium' since it already exists.
# Ignoring reaction 'EX_h2s_medium' since it already exists.
# Ignoring reaction 'EX_h_medium' since it already exists.
# Ignoring reaction 'EX_hdca_medium' since it already exists.
# Ignoring reaction 'EX_hg2_medium' since it already exists.
# Ignoring reaction 'EX_his_L_medium' since it already exists.
# Ignoring reaction 'EX_hxan_medium' since it already exists.
# Ignoring reaction 'EX_k_medium' since it already exists.
# Ignoring reaction 'EX_lac_L_medium' since it already exists.
# Ignoring reaction 'EX_lys_L_medium' since it already exists.
# Ignoring reaction 'EX_malt_medium' since it already exists.
# Ignoring reaction 'EX_malthx_medium' since it already exists.
# Ignoring reaction 'EX_malttr_medium' since it already exists.
# Ignoring reaction 'EX_melib_medium' since it already exists.
# Ignoring reaction 'EX_met_L_medium' since it already exists.
# Ignoring reaction 'EX_metala_medium' since it already exists.
# Ignoring reaction 'EX_mg2_medium' since it already exists.
# Ignoring reaction 'EX_mn2_medium' since it already exists.
# Ignoring reaction 'EX_na1_medium' since it already exists.
# Ignoring reaction 'EX_nac_medium' since it already exists.
# Ignoring reaction 'EX_nh4_medium' since it already exists.
# Ignoring reaction 'EX_o2_medium' since it already exists.
# Ignoring reaction 'EX_ocdca_medium' since it already exists.
# Ignoring reaction 'EX_pb_medium' since it already exists.
# Ignoring reaction 'EX_pi_medium' since it already exists.
# Ignoring reaction 'EX_pnto_R_medium' since it already exists.
# Ignoring reaction 'EX_pro_L_medium' since it already exists.
# Ignoring reaction 'EX_ptrc_medium' since it already exists.
# Ignoring reaction 'EX_pullulan1200_medium' since it already exists.
# Ignoring reaction 'EX_pydx_medium' since it already exists.
# Ignoring reaction 'EX_pydxn_medium' since it already exists.
# Ignoring reaction 'EX_rbflvrd_medium' since it already exists.
# Ignoring reaction 'EX_ribflv_medium' since it already exists.
# Ignoring reaction 'EX_sT_antigen_medium' since it already exists.
# Ignoring reaction 'EX_sT_antigen_rl_medium' since it already exists.
# Ignoring reaction 'EX_sTn_antigen_medium' since it already exists.
# Ignoring reaction 'EX_so4_medium' since it already exists.
# Ignoring reaction 'EX_spmd_medium' since it already exists.
# Ignoring reaction 'EX_starch1200_medium' since it already exists.
# Ignoring reaction 'EX_strch1_medium' since it already exists.
# Ignoring reaction 'EX_strch2_medium' since it already exists.
# Ignoring reaction 'EX_succ_medium' since it already exists.
# Ignoring reaction 'EX_taur_medium' since it already exists.
# Ignoring reaction 'EX_tchola_medium' since it already exists.
# Ignoring reaction 'EX_tdchola_medium' since it already exists.
# Ignoring reaction 'EX_thr_L_medium' since it already exists.
# Ignoring reaction 'EX_thymd_medium' since it already exists.
# Ignoring reaction 'EX_tsul_medium' since it already exists.
# Ignoring reaction 'EX_ttdca_medium' since it already exists.
# Ignoring reaction 'EX_ura_medium' since it already exists.
# Ignoring reaction 'EX_urea_medium' since it already exists.
# Ignoring reaction 'EX_zn2_medium' since it already exists.
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# WARNING: Not all reactions in the model are mass and charge balanced. To check which reactions are imbalanced, please run the get_unbalanced_reactions method of this CommunityModel object
# Generated community model.
# <Model ten_gutControl_model at 0x200feb9baa0>

# %% [markdown]
# ### Getting the Summary and Report for the model

# %%
com_model_obj.summary()
# Out:
# <h3>Objective</h3><p>1.0 community_biomass = 1.0</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>_26dap_M_medium</td>
#       <td>EX__26dap_M_medium</td>
#       <td>0.02501</td>
#       <td>7</td>
#       <td>0.25%</td>
#     </tr>
#     <tr>
#       <td>_4hbz_medium</td>
#       <td>EX__4hbz_medium</td>
#       <td>0.003097</td>
#       <td>7</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>arg_L_medium</td>
#       <td>EX_arg_L_medium</td>
#       <td>0.2498</td>
#       <td>6</td>
#       <td>2.12%</td>
#     </tr>
#     <tr>
#       <td>asn_L_medium</td>
#       <td>EX_asn_L_medium</td>
#       <td>0.2008</td>
#       <td>4</td>
#       <td>1.14%</td>
#     </tr>
#     <tr>
#       <td>ca2_medium</td>
#       <td>EX_ca2_medium</td>
#       <td>0.003097</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cl_medium</td>
#       <td>EX_cl_medium</td>
#       <td>0.003097</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_medium</td>
#       <td>EX_cobalt2_medium</td>
#       <td>0.003097</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_medium</td>
#       <td>EX_cu2_medium</td>
#       <td>0.003097</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cys_L_medium</td>
#       <td>EX_cys_L_medium</td>
#       <td>0.08234</td>
#       <td>3</td>
#       <td>0.35%</td>
#     </tr>
#     <tr>
#       <td>cytd_medium</td>
#       <td>EX_cytd_medium</td>
#       <td>0.0841</td>
#       <td>9</td>
#       <td>1.07%</td>
#     </tr>
#     <tr>
#       <td>dad_2_medium</td>
#       <td>EX_dad_2_medium</td>
#       <td>0.01498</td>
#       <td>10</td>
#       <td>0.21%</td>
#     </tr>
#     <tr>
#       <td>dextrin_medium</td>
#       <td>EX_dextrin_medium</td>
#       <td>0.4328</td>
#       <td>36</td>
#       <td>22.08%</td>
#     </tr>
#     <tr>
#       <td>dgsn_medium</td>
#       <td>EX_dgsn_medium</td>
#       <td>0.01706</td>
#       <td>10</td>
#       <td>0.24%</td>
#     </tr>
#     <tr>
#       <td>duri_medium</td>
#       <td>EX_duri_medium</td>
#       <td>0.01706</td>
#       <td>9</td>
#       <td>0.22%</td>
#     </tr>
#     <tr>
#       <td>fe2_medium</td>
#       <td>EX_fe2_medium</td>
#       <td>0.003097</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe3_medium</td>
#       <td>EX_fe3_medium</td>
#       <td>0.003097</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fol_medium</td>
#       <td>EX_fol_medium</td>
#       <td>0.009289</td>
#       <td>19</td>
#       <td>0.25%</td>
#     </tr>
#     <tr>
#       <td>glu_L_medium</td>
#       <td>EX_glu_L_medium</td>
#       <td>4.67</td>
#       <td>5</td>
#       <td>33.10%</td>
#     </tr>
#     <tr>
#       <td>gthox_medium</td>
#       <td>EX_gthox_medium</td>
#       <td>0.001548</td>
#       <td>20</td>
#       <td>0.04%</td>
#     </tr>
#     <tr>
#       <td>his_L_medium</td>
#       <td>EX_his_L_medium</td>
#       <td>0.07926</td>
#       <td>6</td>
#       <td>0.67%</td>
#     </tr>
#     <tr>
#       <td>ile_L_medium</td>
#       <td>EX_ile_L_medium</td>
#       <td>0.327</td>
#       <td>6</td>
#       <td>2.78%</td>
#     </tr>
#     <tr>
#       <td>k_medium</td>
#       <td>EX_k_medium</td>
#       <td>0.003097</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>lanost_medium</td>
#       <td>EX_lanost_medium</td>
#       <td>0.01405</td>
#       <td>30</td>
#       <td>0.60%</td>
#     </tr>
#     <tr>
#       <td>leu_L_medium</td>
#       <td>EX_leu_L_medium</td>
#       <td>0.4606</td>
#       <td>6</td>
#       <td>3.92%</td>
#     </tr>
#     <tr>
#       <td>lys_L_medium</td>
#       <td>EX_lys_L_medium</td>
#       <td>0.2854</td>
#       <td>6</td>
#       <td>2.43%</td>
#     </tr>
#     <tr>
#       <td>met_L_medium</td>
#       <td>EX_met_L_medium</td>
#       <td>0.1309</td>
#       <td>5</td>
#       <td>0.93%</td>
#     </tr>
#     <tr>
#       <td>mg2_medium</td>
#       <td>EX_mg2_medium</td>
#       <td>0.003097</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_medium</td>
#       <td>EX_mn2_medium</td>
#       <td>0.003097</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mqn7_medium</td>
#       <td>EX_mqn7_medium</td>
#       <td>0.006193</td>
#       <td>46</td>
#       <td>0.40%</td>
#     </tr>
#     <tr>
#       <td>o2_medium</td>
#       <td>EX_o2_medium</td>
#       <td>13.93</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ocdca_medium</td>
#       <td>EX_ocdca_medium</td>
#       <td>0.08518</td>
#       <td>18</td>
#       <td>2.17%</td>
#     </tr>
#     <tr>
#       <td>ocdcea_medium</td>
#       <td>EX_ocdcea_medium</td>
#       <td>0.2184</td>
#       <td>18</td>
#       <td>5.57%</td>
#     </tr>
#     <tr>
#       <td>phe_L_medium</td>
#       <td>EX_phe_L_medium</td>
#       <td>0.1545</td>
#       <td>9</td>
#       <td>1.97%</td>
#     </tr>
#     <tr>
#       <td>pheme_medium</td>
#       <td>EX_pheme_medium</td>
#       <td>0.003097</td>
#       <td>34</td>
#       <td>0.15%</td>
#     </tr>
#     <tr>
#       <td>pi_medium</td>
#       <td>EX_pi_medium</td>
#       <td>0.8121</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pnto_R_medium</td>
#       <td>EX_pnto_R_medium</td>
#       <td>0.006193</td>
#       <td>9</td>
#       <td>0.08%</td>
#     </tr>
#     <tr>
#       <td>pro_L_medium</td>
#       <td>EX_pro_L_medium</td>
#       <td>0.1844</td>
#       <td>5</td>
#       <td>1.31%</td>
#     </tr>
#     <tr>
#       <td>ribflv_medium</td>
#       <td>EX_ribflv_medium</td>
#       <td>0.006193</td>
#       <td>17</td>
#       <td>0.15%</td>
#     </tr>
#     <tr>
#       <td>sheme_medium</td>
#       <td>EX_sheme_medium</td>
#       <td>0.003097</td>
#       <td>42</td>
#       <td>0.18%</td>
#     </tr>
#     <tr>
#       <td>so4_medium</td>
#       <td>EX_so4_medium</td>
#       <td>0.003097</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>spmd_medium</td>
#       <td>EX_spmd_medium</td>
#       <td>0.003097</td>
#       <td>7</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>thm_medium</td>
#       <td>EX_thm_medium</td>
#       <td>0.003097</td>
#       <td>12</td>
#       <td>0.05%</td>
#     </tr>
#     <tr>
#       <td>thr_L_medium</td>
#       <td>EX_thr_L_medium</td>
#       <td>1.561</td>
#       <td>4</td>
#       <td>8.85%</td>
#     </tr>
#     <tr>
#       <td>thymd_medium</td>
#       <td>EX_thymd_medium</td>
#       <td>0.01498</td>
#       <td>10</td>
#       <td>0.21%</td>
#     </tr>
#     <tr>
#       <td>trp_L_medium</td>
#       <td>EX_trp_L_medium</td>
#       <td>0.0472</td>
#       <td>11</td>
#       <td>0.74%</td>
#     </tr>
#     <tr>
#       <td>ttdca_medium</td>
#       <td>EX_ttdca_medium</td>
#       <td>0.02501</td>
#       <td>14</td>
#       <td>0.50%</td>
#     </tr>
#     <tr>
#       <td>tyr_L_medium</td>
#       <td>EX_tyr_L_medium</td>
#       <td>0.1207</td>
#       <td>9</td>
#       <td>1.54%</td>
#     </tr>
#     <tr>
#       <td>uri_medium</td>
#       <td>EX_uri_medium</td>
#       <td>0.09083</td>
#       <td>9</td>
#       <td>1.16%</td>
#     </tr>
#     <tr>
#       <td>val_L_medium</td>
#       <td>EX_val_L_medium</td>
#       <td>0.3522</td>
#       <td>5</td>
#       <td>2.50%</td>
#     </tr>
#     <tr>
#       <td>zn2_medium</td>
#       <td>EX_zn2_medium</td>
#       <td>0.003097</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ac_medium</td>
#       <td>EX_ac_medium</td>
#       <td>-7.818</td>
#       <td>2</td>
#       <td>50.11%</td>
#     </tr>
#     <tr>
#       <td>adn_medium</td>
#       <td>EX_adn_medium</td>
#       <td>-0.006193</td>
#       <td>10</td>
#       <td>0.20%</td>
#     </tr>
#     <tr>
#       <td>co2_medium</td>
#       <td>EX_co2_medium</td>
#       <td>-15.39</td>
#       <td>1</td>
#       <td>49.32%</td>
#     </tr>
#     <tr>
#       <td>glyc_medium</td>
#       <td>EX_glyc_medium</td>
#       <td>-0.03194</td>
#       <td>3</td>
#       <td>0.31%

# %% [markdown]
# - In report, need to check any unbalanced reactions that are not sink/demand (SINK, DM), Exchange (EX), Transport (T_ or TR_) or BIOMASS

# %%
com_model_obj.report()
# Out:
# Note: The model has more than 5000 reactions. Calculation of loops is skipped, as this would take some time. If needed, please run manually via .get_loops()
# Name: ten_gutControl_model
# ------------------
# Model overview
# Model structure: fixed growth rate
# # Metabolites: 37288
# # Constraint (f-) Metabolites: 24201
# # Model Metabolites: 13087
# # Reactions: 41804
# # Constraint (f-) Reactions: 24200
# # Model Reactions: 17604
# # Genes: 7547
# # Members: 10
# Members:
# 	Alistipes_putredinis_DSM_17216
# 	Bacteroides_uniformis_ATCC_8492
# 	Bacteroides_vulgatus_ATCC_8482
# 	Bifidobacterium_adolescentis_ATCC_15703
# 	Bifidobacterium_longum_E18
# 	Escherichia_coli_UTI89_UPEC
# 	Eubacterium_rectale_ATCC_33656
# 	Faecalibacterium_prausnitzii_M21_2
# 	Prevotella_copri_CB7_DSM_18205
# 	Ruminococcus_bromii_L2_63
# Objective in direction max:
# 	1.0*community_biomass - 1.0*community_biomass_reverse_44dc1
# ------------------
# Model quality
# # Reactions unbalanced: 197
# # Reactions able to carry flux without a medium: NaN
# {'community_name': 'ten_gutControl_model',
#  'model_structure': 'fixed growth rate',
#  'num_metabolites': 37288,
#  'num_f_metabolites': 24201,
#  'num_model_metabolites': 13087,
#  'num_reactions': 41804,
#  'num_f_reactions': 24200,
#  'num_model_reactions': 17604,
#  'num_genes': 7547,
#  'member_names': ['Alistipes_putredinis_DSM_17216',
#   'Bacteroides_uniformis_ATCC_8492',
#   'Bacteroides_vulgatus_ATCC_8482',
#   'Bifidobacterium_adolescentis_ATCC_15703',
#   'Bifidobacterium_longum_E18',
#   'Escherichia_coli_UTI89_UPEC',
#   'Eubacterium_rectale_ATCC_33656',
#   'Faecalibacterium_prausnitzii_M21_2',
#   'Prevotella_copri_CB7_DSM_18205',
#   'Ruminococcus_bromii_L2_63'],
#  'num_members': 10,
#  'objective_expression': 1.0*community_biomass - 1.0*community_biomass_reverse_44dc1,
#  'objective_direction': 'max',
#  'unbalanced_reactions': {<Reaction Alistipes_putredinis_DSM_17216_DHNAOPT_Alistipes_putredinis_DSM_17216_c at 0x200fecb0cb0>: {'charge': 2.0},
#   <Reaction Alistipes_putredinis_DSM_17216_DM_Alistipes_putredinis_DSM_17216_clpn180_Alistipes_putredinis_DSM_17216_c at 0x200fecb1070>: {'charge': 2.0,
#    'C': -81.0,
#    'H': -156.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Alistipes_putredinis_DSM_17216_DM_Alistipes_putredinis_DSM_17216_clpnai17_Alistipes_putredinis_DSM_17216_c at 0x200fecb1040>: {'charge': 2.0,
#    'C': -77.0,
#    'H': -148.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Alistipes_putredinis_DSM_17216_DM_Alistipes_putredinis_DSM_17216_clpni17_Alistipes_putredinis_DSM_17216_c at 0x200fecb10a0>: {'charge': 2.0,
#    'C': -77.0,
#    'H': -148.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Alistipes_putredinis_DSM_17216_DM_kdo2lipid4L_Alistipes_putredinis_DSM_17216_c at 0x200fecb10d0>: {'charge': 6.0,
#    'C': -96.0,
#    'H': -170.0,
#    'N': -2.0,
#    'O': -38.0,
#    'P': -2.0},
#   <Reaction Alistipes_putredinis_DSM_17216_EX_biomass_e_Alistipes_putredinis_DSM_17216_c at 0x200fecb1910>: {'X': -1.0},
#   <Reaction Alistipes_putredinis_DSM_17216_GLCP3_Alistipes_putredinis_DSM_17216_c at 0x200fecb33b0>: {'charge': -1.0,
#    'H': -1.0,
#    'X': 1.0},
#   <Reaction Alistipes_putredinis_DSM_17216_dreplication_Alistipes_putredinis_DSM_17216_c at 0x200fed5be90>: {'X': 1.0},
#   <Reaction Alistipes_putredinis_DSM_17216_pbiosynthesis_Alistipes_putredinis_DSM_17216_c at 0x200fed5bf50>: {'X': 1.0},
#   <Reaction Alistipes_putredinis_DSM_17216_rtranscription_Alistipes_putredinis_DSM_17216_c at 0x200fee0c170>: {'X': 1.0},
#   <Reaction Alistipes_putredinis_DSM_17216_biomass374 at 0x200fee0c0b0>: {'charge': 0.8556350000000645,
#    'C': -39.345075000000044,
#    'H': -62.78287350000035,
#    'N': -8.571892499999937,
#    'O': -14.310843000000435,
#    'P': -0.8120675000000127,
#    'S': -0.222525,
#    'X': -2.0,
#    'Co': -0.0030965,
#    'Ca': -0.0030965,
#    'Cl': -0.0030965,
#    'Cu': -0.0030965,
#    'Fe': -0.012386,
#    'K': -0.0030965,
#    'Mg': -0.0030965,
#    'Mn': -0.0030965,
#    'Zn': -0.0030965},
#   <Reaction Bacteroides_uniformis_ATCC_8492_DHNAOPT_Bacteroides_uniformis_ATCC_8492_c at 0x20083739610>: {'charge': 2.0},
#   <Reaction Bacteroides_uniformis_ATCC_8492_DM_4HBA_Bacteroides_uniformis_ATCC_8492_c at 0x20082c61df0>: {'C': -7.0,
#    'H': -8.0,
#    'O': -2.0},
#   <Reaction Bacteroides_uniformis_ATCC_8492_DM_AMOB_Bacteroides_uniformis_ATCC_8492_c at 0x20082c62660>: {'C': -15.0,
#    'H': -19.0,
#    'N': -5.0,
#    'O': -6.0,
#    'S': -1.0},
#   <Reaction Bacteroides_uniformis_ATCC_8492_DM_btn_Bacteroides_uniformis_ATCC_8492_c at 0x20082c63380>: {'charge': 1.0,
#    'C': -10.0,
#    'H': -15.0,
#    'N': -2.0,
#    'O': -3.0,
#    'S': -1.0},
#   <Reaction Bacteroides_uniformis_ATCC_8492_DM_dad_5_Bacteroides_uniformis_ATCC_8492_c at 0x20082c63650>: {'C': -10.0,
#    'H': -13.0,
#    'N': -5.0,
#    'O': -3.0},
#   <Reaction Bacteroides_uniformis_ATCC_8492_DM_dhptd_Bacteroides_uniformis_ATCC_8492_c at 0x20082c635c0>: {'C': -5.0,
#    'H': -8.0,
#    'O': -4.0},
#   <Reaction Bacteroides_uniformis_ATCC_8492_DM_kdo2lipid4L_Bacteroides_uniformis_ATCC_8492_c at 0x20082c63740>: {'charge': 6.0,
#    'C': -96.0,
#    'H': -170.0,
#    'N': -2.0,
#    'O': -38.0,
#    'P': -2.0},
#   <Reaction Bacteroides_uniformis_ATCC_8492_DM_pheme_Bacteroides_uniformis_ATCC_8492_c at 0x20082c637d0>: {'charge': 2.0,
#    'C': -34.0,
#    'H': -30.0,
#    'Fe': -1.0,
#    'N': -4.0,
#    'O': -4.0},
#   <Reaction Bacteroides_uniformis_ATCC_8492_DM_teich_45_BS_Bacteroides_uniformis_ATCC_8492_c at 0x20082c63830>: {'X': -1.0},
#   <Reaction Bacteroides_uniformis_ATCC_8492_EX_biomass_e_Bacteroides_uniformis_ATCC_8492_c at 0x20082b5ecc0>: {'X': -1.0},
#   <Reaction Bacteroides_uniformis_ATCC_8492_GLCP3_Bacteroides_uniformis_ATCC_8492_c at 0x200835db140>: {'charge': -1.0,
#    'H': -1.0,
#    'X': 1.0},
#   <Reaction Bacteroides_uniformis_ATCC_8492_SHCHCC2_Bacteroides_uniformis_ATCC_8492_c at 0x2008373a030>: {'charge': -2.0},
#   <Reaction Bacteroides_uniformis_ATCC_8492_TEICH45_Bacteroides_uniformis_ATCC_8492_c at 0x20082b5e750>: {'charge': 45.0,
#    'C': -630.0,
#    'H': -945.0,
#    'N': -45.0,
#    'O': -630.0,
#    'P': -45.0,
#    'X': 1.0},
#   <Reaction Bacteroides_uniformis_ATCC_8492_dreplication_Bacteroides_uniformis_ATCC_8492_c at 0x20082d69610>: {'X': 1.0},
#   <Reaction Bacteroides_uniformis_ATCC_8492_pbiosynthesis_Bacteroides_uniformis_ATCC_8492_c at 0x20082d69700>: {'X': 1.0},
#   <Reaction Bacteroides_uniformis_ATCC_8492_rtranscription_Bacteroides_uniformis_ATCC_8492_c at 0x20082d69730>: {'X': 1.0},
#   <Reaction Bacteroides_uniformis_ATCC_8492_sink_dmbzid_Bacteroides_uniformis_ATCC_8492_c at 0x20082d69640>: {'C': -9.0,
#    'H': -10.0,
#    'N': -2.0},
#   <Reaction Bacteroides_uniformis_ATCC_8492_sink_s_Bacteroides_uniformis_ATCC_8492_c at 0x20082d69670>: {'S': -1.0},
#   <Reaction Bacteroides_uniformis_ATCC_8492_biomass536 at 0x20081f56660>: {'charge': 1.2464257999999917,
#    'C': -40.58411340000009,
#    'H': -62.38917099999985,
#    'N': -10.503082200000051,
#    'O': -17.114728600000213,
#    'P': -1.16025480000001,
#    'S': -0.2695576,
#    'X': -2.0,
#    'Ca': -0.0078094,
#    'Cl': -0.0078094,
#    'Co': -0.0078094,
#    'Cu': -0.0078094,
#    'Fe': -0.0156188,
#    'K': -0.0078094,
#    'Mg': -0.0078094,
#    'Mn': -0.0078094,
#    'Zn': -0.0078094},
#   <Reaction Bacteroides_vulgatus_ATCC_8482_DHNAOPT_Bacteroides_vulgatus_ATCC_8482_c at 0x20086975340>: {'charge': 2.0},
#   <Reaction Bacteroides_vulgatus_ATCC_8482_DM_4HBA_Bacteroides_vulgatus_ATCC_8482_c at 0x20089784080>: {'C': -7.0,
#    'H': -8.0,
#    'O': -2.0},
#   <Reaction Bacteroides_vulgatus_ATCC_8482_DM_5MTR_Bacteroides_vulgatus_ATCC_8482_c at 0x200897840e0>: {'C': -6.0,
#    'H': -12.0,
#    'O': -4.0,
#    'S': -1.0},
#   <Reaction Bacteroides_vulgatus_ATCC_8482_DM_AMOB_Bacteroides_vulgatus_ATCC_8482_c at 0x20089786330>: {'C': -15.0,
#    'H': -19.0,
#    'N': -5.0,
#    'O': -6.0,
#    'S': -1.0},
#   <Reaction Bacteroides_vulgatus_ATCC_8482_DM_btn_Bacteroides_vulgatus_ATCC_8482_c at 0x20089786ed0>: {'charge': 1.0,
#    'C': -10.0,
#    'H': -15.0,
#    'N': -2.0,
#    'O': -3.0,
#    'S': -1.0},
#   <Reaction Bacteroides_vulgatus_ATCC_8482_DM_Bacteroides_vulgatus_ATCC_8482_clpn180_Bacteroides_vulgatus_ATCC_8482_c at 0x20089786fc0>: {'charge': 2.0,
#    'C': -81.0,
#    'H': -156.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Bacteroides_vulgatus_ATCC_8482_DM_Bacteroides_vulgatus_ATCC_8482_clpnai17_Bacteroides_vulgatus_ATCC_8482_c at 0x20089787050>: {'charge': 2.0,
#    'C': -77.0,
#    'H': -148.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Bacteroides_vulgatus_ATCC_8482_DM_Bacteroides_vulgatus_ATCC_8482_clpni17_Bacteroides_vulgatus_ATCC_8482_c at 0x20089786f90>: {'charge': 2.0,
#    'C': -77.0,
#    'H': -148.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Bacteroides_vulgatus_ATCC_8482_DM_dad_5_Bacteroides_vulgatus_ATCC_8482_c at 0x20089787110>: {'C': -10.0,
#    'H': -13.0,
#    'N': -5.0,
#    'O': -3.0},
#   <Reaction Bacteroides_vulgatus_ATCC_8482_DM_dhptd_Bacteroides_vulgatus_ATCC_8482_c at 0x20089787170>: {'C': -5.0,
#    'H': -8.0,
#    'O': -4.0},
#   <Reaction Bacteroides_vulgatus_ATCC_8482_DM_kdo2lipid4L_Bacteroides_vulgatus_ATCC_8482_c at 0x200897871d0>: {'charge': 6.0,
#    'C': -96.0,
#    'H': -170.0,
#    'N': -2.0,
#    'O': -38.0,
#    'P': -2.0},
#   <Reaction Bacteroides_vulgatus_ATCC_8482_DM_teich_45_BS_Bacteroides_vulgatus_ATCC_8482_c at 0x20089787320>: {'X': -1.0},
#   <Reaction Bacteroides_vulgatus_ATCC_8482_EX_biomass_e_Bacteroides_vulgatus_ATCC_8482_c at 0x20089787470>: {'X': -1.0},
#   <Reaction Bacteroides_vulgatus_ATCC_8482_GLCP3_Bacteroides_vulgatus_ATCC_8482_c at 0x20082f7e2a0>: {'charge': -1.0,
#    'H': -1.0,
#    'X': 1.0},
#   <Reaction Bacteroides_vulgatus_ATCC_8482_SHCHCC2_Bacteroides_vulgatus_ATCC_8482_c at 0x200869b3950>: {'charge': -2.0},
#   <Reaction Bacteroides_vulgatus_ATCC_8482_TEICH45_Bacteroides_vulgatus_ATCC_8482_c at 0x200896a24e0>: {'charge': 45.0,
#    'C': -630.0,
#    'H': -945.0,
#    'N': -45.0,
#    'O': -630.0,
#    'P': -45.0,
#    'X': 1.0},
#   <Reaction Bacteroides_vulgatus_ATCC_8482_dreplication_Bacteroides_vulgatus_ATCC_8482_c at 0x20089855610>: {'X': 1.0},
#   <Reaction Bacteroides_vulgatus_ATCC_8482_pbiosynthesis_Bacteroides_vulgatus_ATCC_8482_c at 0x20089855640>: {'X': 1.0},
#   <Reaction Bacteroides_vulgatus_ATCC_8482_rtranscription_Bacteroides_vulgatus_ATCC_8482_c at 0x20089855760>: {'X': 1.0},
#   <Reaction Bacteroides_vulgatus_ATCC_8482_sink_dmbzid_Bacteroides_vulgatus_ATCC_8482_c at 0x200898550d0>: {'C': -9.0,
#    'H': -10.0,
#    'N': -2.0},
#   <Reaction Bacteroides_vulgatus_ATCC_8482_sink_gthrd_Bacteroides_vulgatus_ATCC_8482_c at 0x200898550a0>: {'charge': 1.0,
#    'C': -10.0,
#    'H': -16.0,
#    'N': -3.0,
#    'O': -6.0,
#    'S': -1.0},
#   <Reaction Bacteroides_vulgatus_ATCC_8482_sink_s_Bacteroides_vulgatus_ATCC_8482_c at 0x200897840b0>: {'S': -1.0},
#   <Reaction Bacteroides_vulgatus_ATCC_8482_biomass345 at 0x20088bf1af0>: {'charge': 0.855651000000081,
#    'C': -39.34615600000004,
#    'H': -62.78396450000044,
#    'N': -8.570865499999943,
#    'O': -14.310895000000304,
#    'P': -0.8120795000000108,
#    'S': -0.222525,
#    'X': -2.0,
#    'Co': -0.0030965,
#    'Ca': -0.0030965,
#    'Cl': -0.0030965,
#    'Cu': -0.0030965,
#    'Fe': -0.012386,
#    'K': -0.0030965,
#    'Mg': -0.0030965,
#    'Mn': -0.0030965,
#    'Zn': -0.0030965},
#   <Reaction Bifidobacterium_adolescentis_ATCC_15703_DHNAOPT_Bifidobacterium_adolescentis_ATCC_15703_c at 0x2008e7870b0>: {'charge': 2.0},
#   <Reaction Bifidobacterium_adolescentis_ATCC_15703_DM_2HYMEPH_Bifidobacterium_adolescentis_ATCC_15703_c at 0x2008e4689b0>: {'C': -7.0,
#    'H': -8.0,
#    'O': -2.0},
#   <Reaction Bifidobacterium_adolescentis_ATCC_15703_DM_5DRIB_Bifidobacterium_adolescentis_ATCC_15703_c at 0x2008e4687a0>: {'C': -5.0,
#    'H': -10.0,
#    'O': -4.0},
#   <Reaction Bifidobacterium_adolescentis_ATCC_15703_DM_5MTR_Bifidobacterium_adolescentis_ATCC_15703_c at 0x2008e468a70>: {'C': -6.0,
#    'H': -12.0,
#    'O': -4.0,
#    'S': -1.0},
#   <Reaction Bifidobacterium_adolescentis_ATCC_15703_DM_GCALD_Bifidobacterium_adolescentis_ATCC_15703_c at 0x2008e468ad0>: {'C': -2.0,
#    'H': -4.0,
#    'O': -2.0},
#   <Reaction Bifidobacterium_adolescentis_ATCC_15703_DM_Bifidobacterium_adolescentis_ATCC_15703_clpn180_Bifidobacterium_adolescentis_ATCC_15703_c at 0x2008e468b90>: {'charge': 2.0,
#    'C': -81.0,
#    'H': -156.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Bifidobacterium_adolescentis_ATCC_15703_DM_Bifidobacterium_adolescentis_ATCC_15703_clpnai17_Bifidobacterium_adolescentis_ATCC_15703_c at 0x2008e468bf0>: {'charge': 2.0,
#    'C': -77.0,
#    'H': -148.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Bifidobacterium_adolescentis_ATCC_15703_DM_Bifidobacterium_adolescentis_ATCC_15703_clpni17_Bifidobacterium_adolescentis_ATCC_15703_c at 0x2008e468c50>: {'charge': 2.0,
#    'C': -77.0,
#    'H': -148.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Bifidobacterium_adolescentis_ATCC_15703_DM_dad_5_Bifidobacterium_adolescentis_ATCC_15703_c at 0x2008e468cb0>: {'C': -10.0,
#    'H': -13.0,
#    'N': -5.0,
#    'O': -3.0},
#   <Reaction Bifidobacterium_adolescentis_ATCC_15703_DM_dhptd_Bifidobacterium_adolescentis_ATCC_15703_c at 0x2008e468d10>: {'C': -5.0,
#    'H': -8.0,
#    'O': -4.0},
#   <Reaction Bifidobacterium_adolescentis_ATCC_15703_DM_kdo2lipid4L_Bifidobacterium_adolescentis_ATCC_15703_c at 0x2008e468d70>: {'charge': 6.0,
#    'C': -96.0,
#    'H': -170.0,
#    'N': -2.0,
#    'O': -38.0,
#    'P': -2.0},
#   <Reaction Bifidobacterium_adolescentis_ATCC_15703_EX_biomass_e_Bifidobacterium_adolescentis_ATCC_15703_c at 0x2008e3cf710>: {'X': -1.0},
#   <Reaction Bifidobacterium_adolescentis_ATCC_15703_GLCP3_Bifidobacterium_adolescentis_ATCC_15703_c at 0x2008e7843b0>: {'charge': -1.0,
#    'H': -1.0,
#    'X': 1.0},
#   <Reaction Bifidobacterium_adolescentis_ATCC_15703_TECAAE_Bifidobacterium_adolescentis_ATCC_15703_c at 0x2008e3ceab0>: {'C': -286.0,
#    'H': -477.0,
#    'N': -47.0,
#    'O': -238.0,
#    'P': -46.0},
#   <Reaction Bifidobacterium_adolescentis_ATCC_15703_TECAGE_Bifidobacterium_adolescentis_ATCC_15703_c at 0x2008e3cec00>: {'charge': 45.0,
#    'C': -421.0,
#    'H': -747.0,
#    'N': -2.0,
#    'O': -463.0,
#    'P': -46.0},
#   <Reaction Bifidobacterium_adolescentis_ATCC_15703_TECAUE_Bifidobacterium_adolescentis_ATCC_15703_c at 0x2008e3ceb70>: {'charge': 45.0,
#    'C': -151.0,
#    'H': -297.0,
#    'N': -2.0,
#    'O': -238.0,
#    'P': -46.0},
#   <Reaction Bifidobacterium_adolescentis_ATCC_15703_dreplication_Bifidobacterium_adolescentis_ATCC_15703_c at 0x2008e3ce630>: {'X': 1.0},
#   <Reaction Bifidobacterium_adolescentis_ATCC_15703_pbiosynthesis_Bifidobacterium_adolescentis_ATCC_15703_c at 0x2008e3cf290>: {'X': 1.0},
#   <Reaction Bifidobacterium_adolescentis_ATCC_15703_rtranscription_Bifidobacterium_adolescentis_ATCC_15703_c at 0x2008e468080>: {'X': 1.0},
#   <Reaction Bifidobacterium_adolescentis_ATCC_15703_sink_gthrd_Bifidobacterium_adolescentis_ATCC_15703_c at 0x2008e468230>: {'charge': 1.0,
#    'C': -10.0,
#    'H': -16.0,
#    'N': -3.0,
#    'O': -6.0,
#    'S': -1.0},
#   <Reaction Bifidobacterium_adolescentis_ATCC_15703_biomass345 at 0x2008dfe2e70>: {'charge': 0.855651000000081,
#    'C': -39.34615600000004,
#    'H': -62.78396450000044,
#    'N': -8.570865499999943,
#    'O': -14.310895000000304,
#    'P': -0.8120795000000108,
#    'S': -0.222525,
#    'X': -2.0,
#    'Co': -0.0030965,
#    'Ca': -0.0030965,
#    'Cl': -0.0030965,
#    'Cu': -0.0030965,
#    'Fe': -0.012386,
#    'K': -0.0030965,
#    'Mg': -0.0030965,
#    'Mn': -0.0030965,
#    'Zn': -0.0030965},
#   <Reaction Bifidobacterium_longum_E18_DHNAOPT_Bifidobacterium_longum_E18_c at 0x200920cbe00>: {'charge': 2.0},
#   <Reaction Bifidobacterium_longum_E18_DM_4HBA_Bifidobacterium_longum_E18_c at 0x2009254b7a0>: {'C': -7.0,
#    'H': -8.0,
#    'O': -2.0},
#   <Reaction Bifidobacterium_longum_E18_DM_5DRIB_Bifidobacterium_longum_E18_c at 0x2009254bbf0>: {'C': -5.0,
#    'H': -10.0,
#    'O': -4.0},
#   <Reaction Bifidobacterium_longum_E18_DM_5MTR_Bifidobacterium_longum_E18_c at 0x2009254b710>: {'C': -6.0,
#    'H': -12.0,
#    'O': -4.0,
#    'S': -1.0},
#   <Reaction Bifidobacterium_longum_E18_DM_GCALD_Bifidobacterium_longum_E18_c at 0x2009254bcb0>: {'C': -2.0,
#    'H': -4.0,
#    'O': -2.0},
#   <Reaction Bifidobacterium_longum_E18_DM_Bifidobacterium_longum_E18_clpn180_Bifidobacterium_longum_E18_c at 0x2009254bc50>: {'charge': 2.0,
#    'C': -81.0,
#    'H': -156.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Bifidobacterium_longum_E18_DM_Bifidobacterium_longum_E18_clpnai17_Bifidobacterium_longum_E18_c at 0x2009254bda0>: {'charge': 2.0,
#    'C': -77.0,
#    'H': -148.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Bifidobacterium_longum_E18_DM_Bifidobacterium_longum_E18_clpni17_Bifidobacterium_longum_E18_c at 0x2009254bd70>: {'charge': 2.0,
#    'C': -77.0,
#    'H': -148.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Bifidobacterium_longum_E18_DM_dad_5_Bifidobacterium_longum_E18_c at 0x2009254bd40>: {'C': -10.0,
#    'H': -13.0,
#    'N': -5.0,
#    'O': -3.0},
#   <Reaction Bifidobacterium_longum_E18_DM_dhptd_Bifidobacterium_longum_E18_c at 0x2009254be90>: {'C': -5.0,
#    'H': -8.0,
#    'O': -4.0},
#   <Reaction Bifidobacterium_longum_E18_DM_kdo2lipid4L_Bifidobacterium_longum_E18_c at 0x2009254b770>: {'charge': 6.0,
#    'C': -96.0,
#    'H': -170.0,
#    'N': -2.0,
#    'O': -38.0,
#    'P': -2.0},
#   <Reaction Bifidobacterium_longum_E18_EX_biomass_e_Bifidobacterium_longum_E18_c at 0x200925495b0>: {'X': -1.0},
#   <Reaction Bifidobacterium_longum_E18_GLCP3_Bifidobacterium_longum_E18_c at 0x200920c9940>: {'charge': -1.0,
#    'H': -1.0,
#    'X': 1.0},
#   <Reaction Bifidobacterium_longum_E18_TECAAE_Bifidobacterium_longum_E18_c at 0x2009246cec0>: {'C': -286.0,
#    'H': -477.0,
#    'N': -47.0,
#    'O': -238.0,
#    'P': -46.0},
#   <Reaction Bifidobacterium_longum_E18_TECAGE_Bifidobacterium_longum_E18_c at 0x2009246cf20>: {'charge': 45.0,
#    'C': -421.0,
#    'H': -747.0,
#    'N': -2.0,
#    'O': -463.0,
#    'P': -46.0},
#   <Reaction Bifidobacterium_longum_E18_TECAUE_Bifidobacterium_longum_E18_c at 0x2009246cf80>: {'charge': 45.0,
#    'C': -151.0,
#    'H': -297.0,
#    'N': -2.0,
#    'O': -238.0,
#    'P': -46.0},
#   <Reaction Bifidobacterium_longum_E18_dreplication_Bifidobacterium_longum_E18_c at 0x2009254a540>: {'X': 1.0},
#   <Reaction Bifidobacterium_longum_E18_pbiosynthesis_Bifidobacterium_longum_E18_c at 0x2009254a5a0>: {'X': 1.0},
#   <Reaction Bifidobacterium_longum_E18_rtranscription_Bifidobacterium_longum_E18_c at 0x2009254a870>: {'X': 1.0},
#   <Reaction Bifidobacterium_longum_E18_sink_gthrd_Bifidobacterium_longum_E18_c at 0x2009254a960>: {'charge': 1.0,
#    'C': -10.0,
#    'H': -16.0,
#    'N': -3.0,
#    'O': -6.0,
#    'S': -1.0},
#   <Reaction Bifidobacterium_longum_E18_biomass345 at 0x20091aa47d0>: {'charge': 0.855651000000081,
#    'C': -39.34615600000004,
#    'H': -62.78396450000044,
#    'N': -8.570865499999943,
#    'O': -14.310895000000304,
#    'P': -0.8120795000000108,
#    'S': -0.222525,
#    'X': -2.0,
#    'Co': -0.0030965,
#    'Ca': -0.0030965,
#    'Cl': -0.0030965,
#    'Cu': -0.0030965,
#    'Fe': -0.012386,
#    'K': -0.0030965,
#    'Mg': -0.0030965,
#    'Mn': -0.0030965,
#    'Zn': -0.0030965},
#   <Reaction Escherichia_coli_UTI89_UPEC_DHNAOPT_Escherichia_coli_UTI89_UPEC_c at 0x20098cfb560>: {'charge': 2.0},
#   <Reaction Escherichia_coli_UTI89_UPEC_DM_4HBA_Escherichia_coli_UTI89_UPEC_c at 0x20097fc8410>: {'C': -7.0,
#    'H': -8.0,
#    'O': -2.0},
#   <Reaction Escherichia_coli_UTI89_UPEC_DM_5DRIB_Escherichia_coli_UTI89_UPEC_c at 0x20097fc8440>: {'C': -5.0,
#    'H': -10.0,
#    'O': -4.0},
#   <Reaction Escherichia_coli_UTI89_UPEC_DM_AMOB_Escherichia_coli_UTI89_UPEC_c at 0x20097fc83e0>: {'C': -15.0,
#    'H': -19.0,
#    'N': -5.0,
#    'O': -6.0,
#    'S': -1.0},
#   <Reaction Escherichia_coli_UTI89_UPEC_DM_HQN_Escherichia_coli_UTI89_UPEC_c at 0x20097fc8470>: {'C': -6.0,
#    'H': -6.0,
#    'O': -2.0},
#   <Reaction Escherichia_coli_UTI89_UPEC_DM_btn_Escherichia_coli_UTI89_UPEC_c at 0x20097fc8530>: {'charge': 1.0,
#    'C': -10.0,
#    'H': -15.0,
#    'N': -2.0,
#    'O': -3.0,
#    'S': -1.0},
#   <Reaction Escherichia_coli_UTI89_UPEC_DM_Escherichia_coli_UTI89_UPEC_clpn140_Escherichia_coli_UTI89_UPEC_c at 0x20097fc84a0>: {'charge': 2.0,
#    'C': -65.0,
#    'H': -124.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Escherichia_coli_UTI89_UPEC_DM_Escherichia_coli_UTI89_UPEC_clpn160_Escherichia_coli_UTI89_UPEC_c at 0x20097fc84d0>: {'charge': 2.0,
#    'C': -73.0,
#    'H': -140.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Escherichia_coli_UTI89_UPEC_DM_Escherichia_coli_UTI89_UPEC_clpn180_Escherichia_coli_UTI89_UPEC_c at 0x20097fc8560>: {'charge': 2.0,
#    'C': -81.0,
#    'H': -156.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Escherichia_coli_UTI89_UPEC_DM_Escherichia_coli_UTI89_UPEC_clpni16_Escherichia_coli_UTI89_UPEC_c at 0x20097fc8590>: {'charge': 2.0,
#    'C': -73.0,
#    'H': -140.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Escherichia_coli_UTI89_UPEC_DM_dad_5_Escherichia_coli_UTI89_UPEC_c at 0x20097fc85c0>: {'C': -10.0,
#    'H': -13.0,
#    'N': -5.0,
#    'O': -3.0},
#   <Reaction Escherichia_coli_UTI89_UPEC_DM_dhptd_Escherichia_coli_UTI89_UPEC_c at 0x20097fc85f0>: {'C': -5.0,
#    'H': -8.0,
#    'O': -4.0},
#   <Reaction Escherichia_coli_UTI89_UPEC_DM_kdo2lipid4L_Escherichia_coli_UTI89_UPEC_c at 0x20097fc8620>: {'charge': 6.0,
#    'C': -96.0,
#    'H': -170.0,
#    'N': -2.0,
#    'O': -38.0,
#    'P': -2.0},
#   <Reaction Escherichia_coli_UTI89_UPEC_EX_biomass_e_Escherichia_coli_UTI89_UPEC_c at 0x20097fc8350>: {'X': -1.0},
#   <Reaction Escherichia_coli_UTI89_UPEC_GLCP3_Escherichia_coli_UTI89_UPEC_c at 0x20098bd78f0>: {'charge': -1.0,
#    'H': -1.0,
#    'X': 1.0},
#   <Reaction Escherichia_coli_UTI89_UPEC_GLCS3_Escherichia_coli_UTI89_UPEC_c at 0x20098bd7680>: {'charge': -1.0,
#    'H': -1.0,
#    'X': -1.0},
#   <Reaction Escherichia_coli_UTI89_UPEC_dreplication_Escherichia_coli_UTI89_UPEC_c at 0x20098635250>: {'X': 1.0},
#   <Reaction Escherichia_coli_UTI89_UPEC_pbiosynthesis_Escherichia_coli_UTI89_UPEC_c at 0x20098635490>: {'X': 1.0},
#   <Reaction Escherichia_coli_UTI89_UPEC_rtranscription_Escherichia_coli_UTI89_UPEC_c at 0x20098635f10>: {'X': 1.0},
#   <Reaction Escherichia_coli_UTI89_UPEC_sink_s_Escherichia_coli_UTI89_UPEC_c at 0x20098635ee0>: {'S': -1.0},
#   <Reaction Escherichia_coli_UTI89_UPEC_biomass525 at 0x20098cfb0b0>: {'charge': 1.1166217999999846,
#    'C': -41.42309740000013,
#    'H': -63.2738709999998,
#    'N': -10.952010200000075,
#    'O': -15.8540166000002,
#    'P': -1.1706787999999961,
#    'S': -0.2695576,
#    'X': -2.0,
#    'Ca': -0.0078094,
#    'Cl': -0.0078094,
#    'Co': -0.0078094,
#    'Cu': -0.0078094,
#    'Fe': -0.0156188,
#    'K': -0.0078094,
#    'Mg': -0.0078094,
#    'Mn': -0.0078094,
#    'Zn': -0.0078094},
#   <Reaction Eubacterium_rectale_ATCC_33656_DM_4HBA_Eubacterium_rectale_ATCC_33656_c at 0x2009cfe9400>: {'C': -7.0,
#    'H': -8.0,
#    'O': -2.0},
#   <Reaction Eubacterium_rectale_ATCC_33656_DM_5DRIB_Eubacterium_rectale_ATCC_33656_c at 0x2009cfe9220>: {'C': -5.0,
#    'H': -10.0,
#    'O': -4.0},
#   <Reaction Eubacterium_rectale_ATCC_33656_DM_5MTR_Eubacterium_rectale_ATCC_33656_c at 0x2009cfe9520>: {'C': -6.0,
#    'H': -12.0,
#    'O': -4.0,
#    'S': -1.0},
#   <Reaction Eubacterium_rectale_ATCC_33656_DM_HQN_Eubacterium_rectale_ATCC_33656_c at 0x2009cfe9550>: {'C': -6.0,
#    'H': -6.0,
#    'O': -2.0},
#   <Reaction Eubacterium_rectale_ATCC_33656_DM_Eubacterium_rectale_ATCC_33656_clpn140_Eubacterium_rectale_ATCC_33656_c at 0x2009cfe9670>: {'charge': 2.0,
#    'C': -65.0,
#    'H': -124.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Eubacterium_rectale_ATCC_33656_DM_Eubacterium_rectale_ATCC_33656_clpn160_Eubacterium_rectale_ATCC_33656_c at 0x2009cfe96a0>: {'charge': 2.0,
#    'C': -73.0,
#    'H': -140.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Eubacterium_rectale_ATCC_33656_DM_Eubacterium_rectale_ATCC_33656_clpn180_Eubacterium_rectale_ATCC_33656_c at 0x2009cfe9730>: {'charge': 2.0,
#    'C': -81.0,
#    'H': -156.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Eubacterium_rectale_ATCC_33656_DM_Eubacterium_rectale_ATCC_33656_clpnai15_Eubacterium_rectale_ATCC_33656_c at 0x2009cfe97c0>: {'charge': 2.0,
#    'C': -69.0,
#    'H': -132.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Eubacterium_rectale_ATCC_33656_DM_Eubacterium_rectale_ATCC_33656_clpnai17_Eubacterium_rectale_ATCC_33656_c at 0x2009cfe9850>: {'charge': 2.0,
#    'C': -77.0,
#    'H': -148.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Eubacterium_rectale_ATCC_33656_DM_Eubacterium_rectale_ATCC_33656_clpni15_Eubacterium_rectale_ATCC_33656_c at 0x2009cfe98b0>: {'charge': 2.0,
#    'C': -69.0,
#    'H': -132.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Eubacterium_rectale_ATCC_33656_DM_Eubacterium_rectale_ATCC_33656_clpni16_Eubacterium_rectale_ATCC_33656_c at 0x2009cfe9910>: {'charge': 2.0,
#    'C': -73.0,
#    'H': -140.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Eubacterium_rectale_ATCC_33656_DM_Eubacterium_rectale_ATCC_33656_clpni17_Eubacterium_rectale_ATCC_33656_c at 0x2009cfe9970>: {'charge': 2.0,
#    'C': -77.0,
#    'H': -148.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Eubacterium_rectale_ATCC_33656_DM_dad_5_Eubacterium_rectale_ATCC_33656_c at 0x2009cfe99d0>: {'C': -10.0,
#    'H': -13.0,
#    'N': -5.0,
#    'O': -3.0},
#   <Reaction Eubacterium_rectale_ATCC_33656_DM_dhptd_Eubacterium_rectale_ATCC_33656_c at 0x2009cfe9a30>: {'C': -5.0,
#    'H': -8.0,
#    'O': -4.0},
#   <Reaction Eubacterium_rectale_ATCC_33656_EX_biomass_e_Eubacterium_rectale_ATCC_33656_c at 0x2009cfe8350>: {'X': -1.0},
#   <Reaction Eubacterium_rectale_ATCC_33656_GLCP3_Eubacterium_rectale_ATCC_33656_c at 0x2009d1d2180>: {'charge': -1.0,
#    'H': -1.0,
#    'X': 1.0},
#   <Reaction Eubacterium_rectale_ATCC_33656_GLCS3_Eubacterium_rectale_ATCC_33656_c at 0x2009d1d20c0>: {'charge': -1.0,
#    'H': -1.0,
#    'X': -1.0},
#   <Reaction Eubacterium_rectale_ATCC_33656_PECTIN_DEGe at 0x2009d1d0ec0>: {'charge': -390.0},
#   <Reaction Eubacterium_rectale_ATCC_33656_SHCHCC2_Eubacterium_rectale_ATCC_33656_c at 0x2009d2e1730>: {'charge': -2.0},
#   <Reaction Eubacterium_rectale_ATCC_33656_TECA4S_Eubacterium_rectale_ATCC_33656_c at 0x2009cde6d50>: {'charge': -30.0,
#    'C': -420.0,
#    'H': -752.0,
#    'N': -30.0,
#    'O': -391.0,
#    'P': -30.0,
#    'X': 1.0},
#   <Reaction Eubacterium_rectale_ATCC_33656_TECAAE_Eubacterium_rectale_ATCC_33656_c at 0x2009cde7170>: {'C': -286.0,
#    'H': -477.0,
#    'N': -47.0,
#    'O': -238.0,
#    'P': -46.0},
#   <Reaction Eubacterium_rectale_ATCC_33656_TECAGE_Eubacterium_rectale_ATCC_33656_c at 0x2009cde7290>: {'charge': 45.0,
#    'C': -421.0,
#    'H': -747.0,
#    'N': -2.0,
#    'O': -463.0,
#    'P': -46.0},
#   <Reaction Eubacterium_rectale_ATCC_33656_TECAUE_Eubacterium_rectale_ATCC_33656_c at 0x2009cde75f0>: {'charge': 45.0,
#    'C': -151.0,
#    'H': -297.0,
#    'N': -2.0,
#    'O': -238.0,
#    'P': -46.0},
#   <Reaction Eubacterium_rectale_ATCC_33656_dreplication_Eubacterium_rectale_ATCC_33656_c at 0x2009cfe8050>: {'X': 1.0},
#   <Reaction Eubacterium_rectale_ATCC_33656_pbiosynthesis_Eubacterium_rectale_ATCC_33656_c at 0x2009cfe9430>: {'X': 1.0},
#   <Reaction Eubacterium_rectale_ATCC_33656_rtranscription_Eubacterium_rectale_ATCC_33656_c at 0x2009cfe9610>: {'X': 1.0},
#   <Reaction Eubacterium_rectale_ATCC_33656_sink_PGPm1_Eubacterium_rectale_ATCC_33656_c at 0x2009cfe9370>: {'X': -1.0},
#   <Reaction Eubacterium_rectale_ATCC_33656_sink_dmbzid_Eubacterium_rectale_ATCC_33656_c at 0x2009cfe97f0>: {'C': -9.0,
#    'H': -10.0,
#    'N': -2.0},
#   <Reaction Eubacterium_rectale_ATCC_33656_sink_gthrd_Eubacterium_rectale_ATCC_33656_c at 0x2009cfe9790>: {'charge': 1.0,
#    'C': -10.0,
#    'H': -16.0,
#    'N': -3.0,
#    'O': -6.0,
#    'S': -1.0},
#   <Reaction Eubacterium_rectale_ATCC_33656_biomass205 at 0x2009c97ec60>: {'charge': 0.6451868000000773,
#    'C': -35.03339320000001,
#    'H': -56.36232159999977,
#    'N': -7.355973799999984,
#    'O': -13.535103700000404,
#    'P': -0.9387297000000587,
#    'S': -0.21809219999999996,
#    'X': -2.0018063,
#    'Co': -0.0079397,
#    'Ca': -0.0079397,
#    'Cl': -0.0079397,
#    'Cu': -0.0079397,
#    'Fe': -0.0317588,
#    'K': -0.0079397,
#    'Mg': -0.0079397,
#    'Mn': -0.0079397,
#    'Zn': -0.0079397},
#   <Reaction Faecalibacterium_prausnitzii_M21_2_DM_5DRIB_Faecalibacterium_prausnitzii_M21_2_c at 0x200a1d7e4e0>: {'C': -5.0,
#    'H': -10.0,
#    'O': -4.0},
#   <Reaction Faecalibacterium_prausnitzii_M21_2_DM_5MTR_Faecalibacterium_prausnitzii_M21_2_c at 0x200a1d7c560>: {'C': -6.0,
#    'H': -12.0,
#    'O': -4.0,
#    'S': -1.0},
#   <Reaction Faecalibacterium_prausnitzii_M21_2_DM_btn_Faecalibacterium_prausnitzii_M21_2_c at 0x200a1d7e570>: {'charge': 1.0,
#    'C': -10.0,
#    'H': -15.0,
#    'N': -2.0,
#    'O': -3.0,
#    'S': -1.0},
#   <Reaction Faecalibacterium_prausnitzii_M21_2_DM_dad_5_Faecalibacterium_prausnitzii_M21_2_c at 0x200a1d7e5d0>: {'C': -10.0,
#    'H': -13.0,
#    'N': -5.0,
#    'O': -3.0},
#   <Reaction Faecalibacterium_prausnitzii_M21_2_DM_dhptd_Faecalibacterium_prausnitzii_M21_2_c at 0x200a1d7e630>: {'C': -5.0,
#    'H': -8.0,
#    'O': -4.0},
#   <Reaction Faecalibacterium_prausnitzii_M21_2_DM_hcys_L_Faecalibacterium_prausnitzii_M21_2_c at 0x200a1d7e690>: {'C': -4.0,
#    'H': -9.0,
#    'N': -1.0,
#    'O': -2.0,
#    'S': -1.0},
#   <Reaction Faecalibacterium_prausnitzii_M21_2_EX_biomass_e_Faecalibacterium_prausnitzii_M21_2_c at 0x200a1d7e600>: {'X': -1.0},
#   <Reaction Faecalibacterium_prausnitzii_M21_2_PECTIN_DEGe at 0x200a208f530>: {'charge': -390.0},
#   <Reaction Faecalibacterium_prausnitzii_M21_2_SHCHCC2_Faecalibacterium_prausnitzii_M21_2_c at 0x200a21dbc20>: {'charge': -2.0},
#   <Reaction Faecalibacterium_prausnitzii_M21_2_TECA4S_Faecalibacterium_prausnitzii_M21_2_c at 0x200a1cc37d0>: {'charge': -30.0,
#    'C': -420.0,
#    'H': -752.0,
#    'N': -30.0,
#    'O': -391.0,
#    'P': -30.0,
#    'X': 1.0},
#   <Reaction Faecalibacterium_prausnitzii_M21_2_TECAAE_Faecalibacterium_prausnitzii_M21_2_c at 0x200a1cc39b0>: {'C': -286.0,
#    'H': -477.0,
#    'N': -47.0,
#    'O': -238.0,
#    'P': -46.0},
#   <Reaction Faecalibacterium_prausnitzii_M21_2_TECAGE_Faecalibacterium_prausnitzii_M21_2_c at 0x200a1cc39e0>: {'charge': 45.0,
#    'C': -421.0,
#    'H': -747.0,
#    'N': -2.0,
#    'O': -463.0,
#    'P': -46.0},
#   <Reaction Faecalibacterium_prausnitzii_M21_2_TECAUE_Faecalibacterium_prausnitzii_M21_2_c at 0x200a1cc3a10>: {'charge': 45.0,
#    'C': -151.0,
#    'H': -297.0,
#    'N': -2.0,
#    'O': -238.0,
#    'P': -46.0},
#   <Reaction Faecalibacterium_prausnitzii_M21_2_dreplication_Faecalibacterium_prausnitzii_M21_2_c at 0x200a1e44770>: {'X': 1.0},
#   <Reaction Faecalibacterium_prausnitzii_M21_2_pbiosynthesis_Faecalibacterium_prausnitzii_M21_2_c at 0x200a1e44a40>: {'X': 1.0},
#   <Reaction Faecalibacterium_prausnitzii_M21_2_rtranscription_Faecalibacterium_prausnitzii_M21_2_c at 0x200a1e45070>: {'X': 1.0},
#   <Reaction Faecalibacterium_prausnitzii_M21_2_sink_PGPm1_Faecalibacterium_prausnitzii_M21_2_c at 0x200a1e44c50>: {'X': -1.0},
#   <Reaction Faecalibacterium_prausnitzii_M21_2_sink_gthrd_Faecalibacterium_prausnitzii_M21_2_c at 0x200a1e44fb0>: {'charge': 1.0,
#    'C': -10.0,
#    'H': -16.0,
#    'N': -3.0,
#    'O': -6.0,
#    'S': -1.0},
#   <Reaction Faecalibacterium_prausnitzii_M21_2_sink_mqn7_Faecalibacterium_prausnitzii_M21_2_c at 0x200a1e44ef0>: {'C': -46.0,
#    'H': -64.0,
#    'O': -2.0},
#   <Reaction Faecalibacterium_prausnitzii_M21_2_sink_mqn8_Faecalibacterium_prausnitzii_M21_2_c at 0x200a1e44f50>: {'C': -51.0,
#    'H': -72.0,
#    'O': -2.0},
#   <Reaction Faecalibacterium_prausnitzii_M21_2_sink_pheme_Faecalibacterium_prausnitzii_M21_2_c at 0x200a1e45160>: {'charge': 2.0,
#    'C': -34.0,
#    'H': -30.0,
#    'Fe': -1.0,
#    'N': -4.0,
#    'O': -4.0},
#   <Reaction Faecalibacterium_prausnitzii_M21_2_sink_q8_Faecalibacterium_prausnitzii_M21_2_c at 0x200a1e45310>: {'C': -49.0,
#    'H': -74.0,
#    'O': -4.0},
#   <Reaction Faecalibacterium_prausnitzii_M21_2_sink_sheme_Faecalibacterium_prausnitzii_M21_2_c at 0x200a1e45220>: {'charge': 8.0,
#    'C': -42.0,
#    'H': -36.0,
#    'Fe': -1.0,
#    'N': -4.0,
#    'O': -16.0},
#   <Reaction Faecalibacterium_prausnitzii_M21_2_biomass224 at 0x200a13a6600>: {'charge': -81.8688371999999,
#    'C': -35.03166020000007,
#    'H': 26.153426400000345,
#    'N': -7.35762580000002,
#    'O': 68.97897429999959,
#    'P': -0.9387117000000758,
#    'S': -0.21809219999999996,
#    'X': -2.0018063,
#    'Co': -0.0079397,
#    'Ca': -0.0079397,
#    'Cl': -0.0079397,
#    'Cu': -0.0079397,
#    'Fe': -0.0317588,
#    'K': -0.0079397,
#    'Mg': -0.0079397,
#    'Mn': -0.0079397,
#    'Zn': -0.0079397},
#   <Reaction Prevotella_copri_CB7_DSM_18205_DHNAOPT_Prevotella_copri_CB7_DSM_18205_c at 0x200a7f40c50>: {'charge': 2.0},
#   <Reaction Prevotella_copri_CB7_DSM_18205_DM_2HYMEPH_Prevotella_copri_CB7_DSM_18205_c at 0x200a79e1e50>: {'C': -7.0,
#    'H': -8.0,
#    'O': -2.0},
#   <Reaction Prevotella_copri_CB7_DSM_18205_DM_4HBA_Prevotella_copri_CB7_DSM_18205_c at 0x200a79e21b0>: {'C': -7.0,
#    'H': -8.0,
#    'O': -2.0},
#   <Reaction Prevotella_copri_CB7_DSM_18205_DM_dhptd_Prevotella_copri_CB7_DSM_18205_c at 0x200a79e00b0>: {'C': -5.0,
#    'H': -8.0,
#    'O': -4.0},
#   <Reaction Prevotella_copri_CB7_DSM_18205_EX_biomass_e_Prevotella_copri_CB7_DSM_18205_c at 0x200a79e2810>: {'X': -1.0},
#   <Reaction Prevotella_copri_CB7_DSM_18205_GLCP3_Prevotella_copri_CB7_DSM_18205_c at 0x200a7df7200>: {'charge': -1.0,
#    'H': -1.0,
#    'X': 1.0},
#   <Reaction Prevotella_copri_CB7_DSM_18205_dreplication_Prevotella_copri_CB7_DSM_18205_c at 0x200a78da9f0>: {'X': 1.0},
#   <Reaction Prevotella_copri_CB7_DSM_18205_pbiosynthesis_Prevotella_copri_CB7_DSM_18205_c at 0x200a78daa80>: {'X': 1.0},
#   <Reaction Prevotella_copri_CB7_DSM_18205_rtranscription_Prevotella_copri_CB7_DSM_18205_c at 0x200a78dad20>: {'X': 1.0},
#   <Reaction Prevotella_copri_CB7_DSM_18205_biomass525 at 0x200a702c560>: {'charge': 1.1166217999999846,
#    'C': -41.42309740000013,
#    'H': -63.2738709999998,
#    'N': -10.952010200000075,
#    'O': -15.8540166000002,
#    'P': -1.1706787999999961,
#    'S': -0.2695576,
#    'X': -2.0,
#    'Ca': -0.0078094,
#    'Cl': -0.0078094,
#    'Co': -0.0078094,
#    'Cu': -0.0078094,
#    'Fe': -0.0156188,
#    'K': -0.0078094,
#    'Mg': -0.0078094,
#    'Mn': -0.0078094,
#    'Zn': -0.0078094},
#   <Reaction Ruminococcus_bromii_L2_63_DM_adocbl_Ruminococcus_bromii_L2_63_c at 0x200ac3873b0>: {'C': -72.0,
#    'H': -100.0,
#    'Co': -1.0,
#    'N': -18.0,
#    'O': -17.0,
#    'P': -1.0},
#   <Reaction Ruminococcus_bromii_L2_63_DM_btn_Ruminococcus_bromii_L2_63_c at 0x200ac386e40>: {'charge': 1.0,
#    'C': -10.0,
#    'H': -15.0,
#    'N': -2.0,
#    'O': -3.0,
#    'S': -1.0},
#   <Reaction Ruminococcus_bromii_L2_63_DM_Ruminococcus_bromii_L2_63_clpn140_Ruminococcus_bromii_L2_63_c at 0x200ac387ef0>: {'charge': 2.0,
#    'C': -65.0,
#    'H': -124.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Ruminococcus_bromii_L2_63_DM_Ruminococcus_bromii_L2_63_clpn160_Ruminococcus_bromii_L2_63_c at 0x200ac387f50>: {'charge': 2.0,
#    'C': -73.0,
#    'H': -140.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Ruminococcus_bromii_L2_63_DM_Ruminococcus_bromii_L2_63_clpn180_Ruminococcus_bromii_L2_63_c at 0x200ac386780>: {'charge': 2.0,
#    'C': -81.0,
#    'H': -156.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Ruminococcus_bromii_L2_63_DM_Ruminococcus_bromii_L2_63_clpni16_Ruminococcus_bromii_L2_63_c at 0x200ac387fe0>: {'charge': 2.0,
#    'C': -73.0,
#    'H': -140.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Ruminococcus_bromii_L2_63_DM_dhptd_Ruminococcus_bromii_L2_63_c at 0x200ac387ce0>: {'C': -5.0,
#    'H': -8.0,
#    'O': -4.0},
#   <Reaction Ruminococcus_bromii_L2_63_EX_biomass_e_Ruminococcus_bromii_L2_63_c at 0x200ac384dd0>: {'X': -1.0},
#   <Reaction Ruminococcus_bromii_L2_63_GLCP3_Ruminococcus_bromii_L2_63_c at 0x200ac6d3650>: {'charge': -1.0,
#    'H': -1.0,
#    'X': 1.0},
#   <Reaction Ruminococcus_bromii_L2_63_GLCS3_Ruminococcus_bromii_L2_63_c at 0x200ac6d3800>: {'charge': -1.0,
#    'H': -1.0,
#    'X': -1.0},
#   <Reaction Ruminococcus_bromii_L2_63_TECAAE_Ruminococcus_bromii_L2_63_c at 0x200ac3847a0>: {'C': -286.0,
#    'H': -477.0,
#    'N': -47.0,
#    'O': -238.0,
#    'P': -46.0},
#   <Reaction Ruminococcus_bromii_L2_63_TECAGE_Ruminococcus_bromii_L2_63_c at 0x200ac384530>: {'charge': 45.0,
#    'C': -421.0,
#    'H': -747.0,
#    'N': -2.0,
#    'O': -463.0,
#    'P': -46.0},
#   <Reaction Ruminococcus_bromii_L2_63_TECAUE_Ruminococcus_bromii_L2_63_c at 0x200ac3847d0>: {'charge': 45.0,
#    'C': -151.0,
#    'H': -297.0,
#    'N': -2.0,
#    'O': -238.0,
#    'P': -46.0},
#   <Reaction Ruminococcus_bromii_L2_63_dreplication_Ruminococcus_bromii_L2_63_c at 0x200ac384c50>: {'X': 1.0},
#   <Reaction Ruminococcus_bromii_L2_63_pbiosynthesis_Ruminococcus_bromii_L2_63_c at 0x200ac384da0>: {'X': 1.0},
#   <Reaction Ruminococcus_bromii_L2_63_rtranscription_Ruminococcus_bromii_L2_63_c at 0x200ac384fb0>: {'X': 1.0},
#   <Reaction Ruminococcus_bromii_L2_63_biomass525 at 0x200abf14a40>: {'charge': 1.1166217999999846,
#    'C': -41.42309740000013,
#    'H': -63.2738709999998,
#    'N': -10.952010200000075,
#    'O': -15.8540166000002,
#    'P': -1.1706787999999961,
#    'S': -0.2695576,
#    'X': -2.0,
#    'Ca': -0.0078094,
#    'Cl': -0.0078094,
#    'Co': -0.0078094,
#    'Cu': -0.0078094,
#    'Fe': -0.0156188,
#    'K': -0.0078094,
#    'Mg': -0.0078094,
#    'Mn': -0.0078094,
#    'Zn': -0.0078094}},
#  'num_unbalanced_reactions': 197,
#  'reactions_in_loops': 'NaN',
#  'num_loop_reactions': 'NaN'}

# %% [markdown]
# - Checking if there are any thermodynamically infeasible cycles

# %%
com_model_obj.get_loops()
# taking too long to run so I stopped it
# could be a problem and will have to
# Out:
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\medium\boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 com_model_obj.get_loops()
#
# File c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\pycomo\pycomo_models.py:886, in CommunityModel.get_loops(self)
#     883 no_medium = {}
#     884 self.model.medium = no_medium
# --> 886 solution_df = find_loops_in_model(self.convert_to_model_without_fraction_metabolites())
#     888 self.model.medium = original_medium
#     889 return solution_df[
#     890     (~ solution_df["min_flux"].apply(close_to_zero)) | (~ solution_df["max_flux"].apply(close_to_zero))]
#
# File c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\pycomo\pycomo_models.py:1473, in CommunityModel.convert_to_model_without_fraction_metabolites(self)
#    1471     rxn.upper_bound = coeff / self._dummy_metabolite_scaling_factor
#    1472     rxn.add_metabolites({metabolite: 0}, combine=False)
# -> 1473     reaction.add_metabolites({metabolite: 0}, combine=False)
#    1474     metabolite.remove_from_model(True)
#    1475 elif "_f_biomass_met" in metabolite.id:
#
# File c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\cobra\core\reaction.py:1281, in Reaction.add_metabolites(self, metabolites_to_add, combine, reversibly)
#    1277     model.add_metabolites(new_metabolites)
#    1279     for metabolite, coefficient in self._metabolites.items():
#    1280         model.constraints[metabolite.id].set_linear_coefficients(
# -> 1281             {
#    1282                 self.forward_variable: coefficient,
#    1283                 self.reverse_variable: -coefficient,
#    1284             }
#    1285         )
#    1287 for metabolite, the_coefficient in list(self._metabolites.items()):
#    1288     if the_coefficient == 0:
#    1289         # make the metabolite aware that it no longer participates
#    1290         # in this reaction
#
# File c:\Users\tobyl\miniconda3\envs\masterswork\Lib\site-packages\sympy\core\basic.py:189, in Basic.__hash__(self)
#     186         raise NotImplementedError(msg)
#     187     return super().__reduce_ex__(protocol)
# --> 189 def __hash__(self) -> int:
#     190     # hash cannot be cached using cache_it because infinite recurrence
#     191     # occurs as hash is needed for setting cache dictionary keys
#     192     h = self._mhash
#     193     if h is None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Step 3: Converting to fixed abundances as we are modelling specific conditions

# %%
# creating the abundance_dict
abundance_dict = {'Alistipes_putredinis_DSM_17216':  0.058704, 
                  'Bacteroides_uniformis_ATCC_8492': 0.077082,
                  'Bacteroides_vulgatus_ATCC_8482': 0.064064,
                  'Bifidobacterium_adolescentis_ATCC_15703': 0.094908,
                  'Bifidobacterium_longum_E18': 0.073637,
                  'Escherichia_coli_UTI89_UPEC': 0.064846,
                  'Eubacterium_rectale_ATCC_33656': 0.146876,
                  'Faecalibacterium_prausnitzii_M21_2': 0.241639,
                  'Prevotella_copri_CB7_DSM_18205': 0.060178,
                  'Ruminococcus_bromii_L2_63': 0.118065}
print(sum(abundance_dict.values()))
print(abundance_dict)
# Out:
# 0.999999
# {'Alistipes_putredinis_DSM_17216': 0.058704, 'Bacteroides_uniformis_ATCC_8492': 0.077082, 'Bacteroides_vulgatus_ATCC_8482': 0.064064, 'Bifidobacterium_adolescentis_ATCC_15703': 0.094908, 'Bifidobacterium_longum_E18': 0.073637, 'Escherichia_coli_UTI89_UPEC': 0.064846, 'Eubacterium_rectale_ATCC_33656': 0.146876, 'Faecalibacterium_prausnitzii_M21_2': 0.241639, 'Prevotella_copri_CB7_DSM_18205': 0.060178, 'Ruminococcus_bromii_L2_63': 0.118065}

# %%
# converting to fixed abundance model and then adding the abundances from abundance_dict
com_model_obj.convert_to_fixed_abundance()
com_model_obj.apply_fixed_abundance(abundance_dict)

# summarising the model
com_model_obj.summary()
# Out:
# <h3>Objective</h3><p>1.0 community_biomass = 52.67399370670066</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>MGlcn178_medium</td>
#       <td>EX_MGlcn178_medium</td>
#       <td>0.09448</td>
#       <td>66</td>
#       <td>0.05%</td>
#     </tr>
#     <tr>
#       <td>MGlcn181_medium</td>
#       <td>EX_MGlcn181_medium</td>
#       <td>0.1125</td>
#       <td>74</td>
#       <td>0.06%</td>
#     </tr>
#     <tr>
#       <td>_12dgr180_medium</td>
#       <td>EX__12dgr180_medium</td>
#       <td>0.4136</td>
#       <td>39</td>
#       <td>0.12%</td>
#     </tr>
#     <tr>
#       <td>_26dap_M_medium</td>
#       <td>EX__26dap_M_medium</td>
#       <td>0.2798</td>
#       <td>7</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <td>_2obut_medium</td>
#       <td>EX__2obut_medium</td>
#       <td>1.103</td>
#       <td>4</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>_4abz_medium</td>
#       <td>EX__4abz_medium</td>
#       <td>0.04644</td>
#       <td>7</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>_4hbz_medium</td>
#       <td>EX__4hbz_medium</td>
#       <td>0.009575</td>
#       <td>7</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>acald_medium</td>
#       <td>EX_acald_medium</td>
#       <td>373.3</td>
#       <td>2</td>
#       <td>5.62%</td>
#     </tr>
#     <tr>
#       <td>acgam_medium</td>
#       <td>EX_acgam_medium</td>
#       <td>2.529</td>
#       <td>8</td>
#       <td>0.15%</td>
#     </tr>
#     <tr>
#       <td>acnam_medium</td>
#       <td>EX_acnam_medium</td>
#       <td>0.6317</td>
#       <td>11</td>
#       <td>0.05%</td>
#     </tr>
#     <tr>
#       <td>adn_medium</td>
#       <td>EX_adn_medium</td>
#       <td>21.01</td>
#       <td>10</td>
#       <td>1.58%</td>
#     </tr>
#     <tr>
#       <td>alahis_medium</td>
#       <td>EX_alahis_medium</td>
#       <td>1.359</td>
#       <td>9</td>
#       <td>0.09%</td>
#     </tr>
#     <tr>
#       <td>alathr_medium</td>
#       <td>EX_alathr_medium</td>
#       <td>122.5</td>
#       <td>7</td>
#       <td>6.46%</td>
#     </tr>
#     <tr>
#       <td>amp_medium</td>
#       <td>EX_amp_medium</td>
#       <td>15.81</td>
#       <td>10</td>
#       <td>1.19%</td>
#     </tr>
#     <tr>
#       <td>arabinogal_medium</td>
#       <td>EX_arabinogal_medium</td>
#       <td>0.003436</td>
#       <td>3862</td>
#       <td>0.10%</td>
#     </tr>
#     <tr>
#       <td>arabinoxyl_medium</td>
#       <td>EX_arabinoxyl_medium</td>
#       <td>0.4142</td>
#       <td>276</td>
#       <td>0.86%</td>
#     </tr>
#     <tr>
#       <td>arg_L_medium</td>
#       <td>EX_arg_L_medium</td>
#       <td>4.684</td>
#       <td>6</td>
#       <td>0.21%</td>
#     </tr>
#     <tr>
#       <td>asn_L_medium</td>
#       <td>EX_asn_L_medium</td>
#       <td>16.11</td>
#       <td>4</td>
#       <td>0.49%</td>
#     </tr>
#     <tr>
#       <td>btn_medium</td>
#       <td>EX_btn_medium</td>
#       <td>0.02416</td>
#       <td>10</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ca2_medium</td>
#       <td>EX_ca2_medium</td>
#       <td>0.3417</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cgly_medium</td>
#       <td>EX_cgly_medium</td>
#       <td>118.4</td>
#       <td>5</td>
#       <td>4.45%</td>
#     </tr>
#     <tr>
#       <td>cholate_medium</td>
#       <td>EX_cholate_medium</td>
#       <td>102.1</td>
#       <td>24</td>
#       <td>18.45%</td>
#     </tr>
#     <tr>
#       <td>chor_medium</td>
#       <td>EX_chor_medium</td>
#       <td>1.098</td>
#       <td>10</td>
#       <td>0.08%</td>
#     </tr>
#     <tr>
#       <td>cit_medium</td>
#       <td>EX_cit_medium</td>
#       <td>7.467</td>
#       <td>6</td>
#       <td>0.34%</td>
#     </tr>
#     <tr>
#       <td>cl_medium</td>
#       <td>EX_cl_medium</td>
#       <td>0.3417</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_medium</td>
#       <td>EX_cobalt2_medium</td>
#       <td>0.3417</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_medium</td>
#       <td>EX_cu2_medium</td>
#       <td>0.3417</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>dad_2_medium</td>
#       <td>EX_dad_2_medium</td>
#       <td>0.8381</td>
#       <td>10</td>
#       <td>0.06%</td>
#     </tr>
#     <tr>
#       <td>dcyt_medium</td>
#       <td>EX_dcyt_medium</td>
#       <td>6.431</td>
#       <td>9</td>
#       <td>0.44%</td>
#     </tr>
#     <tr>
#       <td>ddca_medium</td>
#       <td>EX_ddca_medium</td>
#       <td>3.101</td>
#       <td>12</td>
#       <td>0.28%</td>
#     </tr>
#     <tr>
#       <td>dextrin_medium</td>
#       <td>EX_dextrin_medium</td>
#       <td>3.839</td>
#       <td>36</td>
#       <td>1.04%</td>
#     </tr>
#     <tr>
#       <td>dgsn_medium</td>
#       <td>EX_dgsn_medium</td>
#       <td>0.8977</td>
#       <td>10</td>
#       <td>0.07%</td>
#     </tr>
#     <tr>
#       <td>dpcoa_medium</td>
#       <td>EX_dpcoa_medium</td>
#       <td>0.09713</td>
#       <td>21</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <td>dtmp_medium</td>
#       <td>EX_dtmp_medium</td>
#       <td>0.07305</td>
#       <td>10</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <td>etoh_medium</td>
#       <td>EX_etoh_medium</td>
#       <td>26.05</td>
#       <td>2</td>
#       <td>0.39%</td>
#     </tr>
#     <tr>
#       <td>fe2_medium</td>
#       <td>EX_fe2_medium</td>
#       <td>0.5093</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe3_medium</td>
#       <td>EX_fe3_medium</td>
#       <td>0.3297</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fol_medium</td>
#       <td>EX_fol_medium</td>
#       <td>0.5836</td>
#       <td>19</td>
#       <td>0.08%</td>
#     </tr>
#     <tr>
#       <td>fum_medium</td>
#       <td>EX_fum_medium</td>
#       <td>4.115</td>
#       <td>4</td>
#       <td>0.12%</td>
#     </tr>
#     <tr>
#       <td>gln_L_medium</td>
#       <td>EX_gln_L_medium</td>
#       <td>101.5</td>
#       <td>5</td>
#       <td>3.82%</td>
#     </tr>
#     <tr>
#       <td>glyasn_medium</td>
#       <td>EX_glyasn_medium</td>
#       <td>102.8</td>
#       <td>6</td>
#       <td>4.64%</td>
#     </tr>
#     <tr>
#       <td>glyc3p_medium</td>
#       <td>EX_glyc3p_medium</td>
#       <td>38.36</td>
#       <td>3</td>
#       <td>0.87%</td>
#     </tr>
#     <tr>
#       <td>glygln_medium</td>
#       <td>EX_glygln_medium</td>
#       <td>50.54</td>
#       <td>7</td>
#       <td>2.66%</td>
#     </tr>
#     <tr>
#       <td>glyleu_medium</td>
#       <td>EX_glyleu_medium</td>
#       <td>45.58</td>
#       <td>8</td>
#       <td>2.74%</td>
#     </tr>
#     <tr>
#       <td>glymet_medium</td>
#       <td>EX_glymet_medium</td>
#       <td>0.6538</td>
#       <td>7</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>glyphe_medium</td>
#       <td>EX_glyphe_medium</td>
#       <td>2.243</td>
#       <td>11</td>
#       <td>0.19%</td>
#     </tr>
#     <tr>
#       <td>glypro_medium</td>
#       <td>EX_glypro_medium</td>
#       <td>2.05</td>
#       <td>7</td>
#       <td>0.11%</td>
#     </tr>
#     <tr>
#       <td>glytyr_medium</td>
#       <td>EX_glytyr_medium</td>
#       <td>1.413</td>
#       <td>11</td>
#       <td>0.12%</td>
#     </tr>
#     <tr>
#       <td>gsn_medium</td>
#       <td>EX_gsn_medium</td>
#       <td>0.9542</td>
#       <td>10</td>
#       <td>0.07%</td>
#     </tr>
#     <tr>
#       <td>gthox_medium</td>
#       <td>EX_gthox_medium</td>
#       <td>0.004787</td>
#       <td>20</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2s_medium</td>
#       <td>EX_h2s_medium</td>
#       <td>0.5428</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>his_L_medium</td>
#       <td>EX_his_L_medium</td>
#       <td>2.159</td>
#       <td>6</td>
#       <td>0.10%</td>
#     </tr>
#     <tr>
#       <td>ile_L_medium</td>
#       <td>EX_ile_L_medium</td>
#       <td>9.325</td>
#       <td>6</td>
#       <td>0.42%</td>
#     </tr>
#     <tr>
#       <td>inulin_medium</td>
#       <td>EX_inulin_medium</td>
#       <td>7.113</td>
#       <td>180</td>
#       <td>9.64%</td>
#     </tr>
#     <tr>
#       <td>k_medium</td>
#       <td>EX_k_medium</td>
#       <td>0.3417</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>lanost_medium</td>
#       <td>EX_lanost_medium</td>
#       <td>0.04
